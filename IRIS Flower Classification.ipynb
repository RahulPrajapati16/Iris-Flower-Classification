# %% [markdown]
# # *Importing The Required Modules*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import seaborn as sns

# %% [markdown]
# # *Loading the Dataset*

# %%
df = pd.read_csv(r"C:\Users\rk991\OneDrive\Desktop\Oasis Internship\iris flower classification\Iris.csv")

# %% [markdown]
# ***Now take a look of the IRIS Data***

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ***Now removing the unwanted column***

# %%
df = df.drop(columns = ['Id'])

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ***Now describing the basic Stats about the IRIS Data***

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ***Now displaying the basic info about the IRIS Dataset***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ***Now checking for the null values in the IRIS Dataset***

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # *Now doing the Exploratory Data Analysis (EDA)*

# %% [markdown]
# ***Plotting the Histogram***

# %%
df['SepalLengthCm'].hist(color = "purple")
plt.xlabel('Sepal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['SepalWidthCm'].hist(color = "purple")
plt.xlabel('Sepal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['PetalLengthCm'].hist(color = "purple")
plt.xlabel('Petal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['SepalWidthCm'].hist(color = "purple")
plt.xlabel('Sepal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ***Now Plotting the Scaterplot***

# %%
Colors = ["orange","purple","brown"]
species = ["Iris-virginica","Iris-versicolor","Iris-setosa"]

# %%
for i in range(3):
    x = df[df["Species"] == species[i]]
    plt.scatter(x["SepalLengthCm"], x["SepalWidthCm"] , c = Colors[i], label = species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
    x = df[df["Species"] == species[i]]
    plt.scatter(x["PetalLengthCm"], x["PetalWidthCm"] , c = Colors[i], label = species[i])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
for i in range(3):
    x = df[df["Species"] == species[i]]
    plt.scatter(x["SepalLengthCm"], x["PetalLengthCm"] , c = Colors[i], label = species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
for i in range(3):
    x = df[df["Species"] == species[i]]
    plt.scatter(x["SepalWidthCm"], x["PetalWidthCm"] , c = Colors[i], label = species[i])
plt.xlabel("Sepal Width")
plt.ylabel("Sepal Width")
plt.legend()

# %% [markdown]
# ## ***Coorelation Matrix***

# %%
x = df.drop(columns = ["Species"])
y = df['Species']
x.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = x.corr()
fig, ax = plt.subplots(figsize=(5,4))
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## ***Label Encoder***

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # *Model Training*

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns = ["Species"])
y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)

# %% [markdown]
# ***Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# ***Model Training***

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\rk991\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ***Checking the Accuracy of the model***

# %%
print("Accuracy: ",model.score(x_test, y_test) *100)
# Out:
# Accuracy:  95.55555555555556

# %% [markdown]
# ***Now importing some other models***\
# ***Importing K-nearest neighbour (KNN)***

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_test, y_test)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test) *100)
# Out:
# Accuracy:  95.55555555555556

# %% [markdown]
# ***Importing Decision tree***

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_test, y_test)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test) *100)
# Out:
# Accuracy:  100.0
